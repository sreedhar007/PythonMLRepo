# %%
def myfunc():
  inputchar=input('Enter alphabet: ')
  if(len(inputchar)==1):
    if inputchar in ['a','e','i','o','u']:
      return True
      print('True')
    else:
      return False
      print('False')
  else:
    print('Enter the character of Length 1')

myfunc()
# Out:
# Enter alphabet: o
# True
