# %%
"""
Write a program which accepts a sequence of comma-separated numbers from console and generate a list
"""

values=input('Enter comma separated numbers:')
list=values.split(',')
print(list)
# Out:
# Enter comma separated numbers:1,5,88,99,6
# ['1', '5', '88', '99', '6']
