# %%
import functools

def filter_long_words(sequence,inte):
  result=[]
  for item in sequence:
    if(len(item)>inte):
      result.append(item)
    else:
      pass
  print(result)
l=['abc','bvv','klio','kk','kklo']
inte=3

filter_long_words(l,inte)
# Out:
# ['klio', 'kklo']
