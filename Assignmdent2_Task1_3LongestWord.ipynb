# %%
def longestWord(sequence):
  longest=sequence[0]
  for item in sequence:
    if(len(item)>=len(longest)):
      longest=item
  print('Longest Word in th list is:',longest)

l=['USA','UK','SPAIN','RUSSIA','INDIA',]
longestWord(l)
# Out:
# Longest Word in th list is: RUSSIA
